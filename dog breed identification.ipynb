# %%
# Importing library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import Adam

# %%
# Read the labels.csv file and check shape and records
labels_all = pd.read_csv("C:/Users/yuvas/OneDrive/Desktop/mini project/archive/labels.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
# Loading number or each breed
breed_all = labels_all['breed']
breed_count = breed_all.value_counts()
breed_count.head()
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: breed, dtype: int64

# %%
# Selecting all breeds because i have high computation power
CLASS_NAME = ['scottish_deerhound', 'maltese_dog', 'afghan_hound', 'entlebucher', 'bernese_mountain_dog']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAME))]
labels = labels.reset_index()
labels.head()
# Out:
#    index                                id               breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64  scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec         maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44  scottish_deerhound
# 3     80  01ee3c7ff9bcaba9874183135877670e         entlebucher
# 4     88  021b5a49189665c0442c19b5b33e8cf1         entlebucher

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAME)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    img = image.load_img('C:/Users/yuvas/OneDrive/Desktop/mini project/archive/train/%s.jpg' % labels['id'][i], target_size=(224, 224))
    img = image.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0

# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 588/588 [00:04<00:00, 133.23it/s]
# Train Images shape:  (588, 224, 224, 3)  size: 88,510,464
# One-hot encoded output shape:  (588, 5)  size: 2,940

# %%
# Building the Model
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAME), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 64)      4864
#
#  max_pooling2d (MaxPooling2  (None, 110, 110, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 32)      18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 16)        25104
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 16)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 8)         3208
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 8)         0
#  g2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 162749 (635.74 KB)
# Trainable params: 162749 (635.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %%
# Training the model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, Y_val))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 70s 12s/step - loss: 5.4095 - accuracy: 0.2057 - val_loss: 5.3742 - val_accuracy: 0.1415
# Epoch 2/100
# 4/4 [==============================] - 46s 10s/step - loss: 5.3583 - accuracy: 0.1891 - val_loss: 5.3274 - val_accuracy: 0.1226
# Epoch 3/100
# 4/4 [==============================] - 51s 13s/step - loss: 5.3102 - accuracy: 0.2199 - val_loss: 5.2799 - val_accuracy: 0.1698
# Epoch 4/100
# 4/4 [==============================] - 63s 14s/step - loss: 5.2630 - accuracy: 0.2317 - val_loss: 5.2352 - val_accuracy: 0.1887
# Epoch 5/100
# 4/4 [==============================] - 50s 11s/step - loss: 5.2171 - accuracy: 0.2506 - val_loss: 5.1920 - val_accuracy: 0.2170
# Epoch 6/100
# 4/4 [==============================] - 51s 11s/step - loss: 5.1710 - accuracy: 0.2482 - val_loss: 5.1472 - val_accuracy: 0.2170
# Epoch 7/100
# 4/4 [==============================] - 50s 11s/step - loss: 5.1251 - accuracy: 0.2506 - val_loss: 5.1019 - val_accuracy: 0.2075
# Epoch 8/100
# 4/4 [==============================] - 48s 11s/step - loss: 5.0795 - accuracy: 0.2671 - val_loss: 5.0562 - val_accuracy: 0.1981
# Epoch 9/100
# 4/4 [==============================] - 45s 11s/step - loss: 5.0345 - accuracy: 0.2884 - val_loss: 5.0135 - val_accuracy: 0.2642
# Epoch 10/100
# 4/4 [==============================] - 44s 10s/step - loss: 4.9891 - accuracy: 0.3073 - val_loss: 4.9712 - val_accuracy: 0.2453
# Epoch 11/100
# 4/4 [==============================] - 50s 11s/step - loss: 4.9443 - accuracy: 0.3002 - val_loss: 4.9275 - val_accuracy: 0.2170
# Epoch 12/100
# 4/4 [==============================] - 51s 12s/step - loss: 4.8993 - accuracy: 0.3286 - val_loss: 4.8840 - val_accuracy: 0.1887
# Epoch 13/100
# 4/4 [==============================] - 48s 11s/step - loss: 4.8548 - accuracy: 0.3452 - val_loss: 4.8459 - val_accuracy: 0.1981
# Epoch 14/100
# 4/4 [==============================] - 52s 12s/step - loss: 4.8112 - accuracy: 0.3357 - val_loss: 4.8006 - val_accuracy: 0.1981
# Epoch 15/100
# 4/4 [==============================] - 46s 11s/step - loss: 4.7651 - accuracy: 0.3428 - val_loss: 4.7566 - val_accuracy: 0.2075
# Epoch 16/100
# 4/4 [==============================] - 51s 12s/step - loss: 4.7207 - accuracy: 0.3452 - val_loss: 4.7145 - val_accuracy: 0.2075
# Epoch 17/100
# 4/4 [==============================] - 51s 11s/step - loss: 4.6759 - accuracy: 0.3168 - val_loss: 4.6681 - val_accuracy: 0.2358
# Epoch 18/100
# 4/4 [==============================] - 49s 11s/step - loss: 4.6328 - accuracy: 0.3475 - val_loss: 4.6191 - val_accuracy: 0.2925
# Epoch 19/100
# 4/4 [==============================] - 47s 11s/step - loss: 4.5849 - accuracy: 0.3499 - val_loss: 4.5764 - val_accuracy: 0.3019
# Epoch 20/100
# 4/4 [==============================] - 49s 11s/step - loss: 4.5310 - accuracy: 0.3948 - val_loss: 4.5211 - val_accuracy: 0.3868
# Epoch 21/100
# 4/4 [==============================] - 48s 11s/step - loss: 4.4823 - accuracy: 0.4350 - val_loss: 4.4678 - val_accuracy: 0.3679
# Epoch 22/100
# 4/4 [==============================] - 52s 12s/step - loss: 4.4209 - accuracy: 0.4397 - val_loss: 4.4148 - val_accuracy: 0.3491
# Epoch 23/100
# 4/4 [==============================] - 51s 11s/step - loss: 4.3845 - accuracy: 0.4255 - val_loss: 4.3594 - val_accuracy: 0.3774
# Epoch 24/100
# 4/4 [==============================] - 47s 11s/step - loss: 4.3158 - accuracy: 0.4515 - val_loss: 4.3012 - val_accuracy: 0.3679
# Epoch 25/100
# 4/4 [==============================] - 43s 10s/step - loss: 4.2561 - accuracy: 0.4681 - val_loss: 4.2553 - val_accuracy: 0.3585
# Epoch 26/100
# 4/4 [==============================] - 53s 12s/step - loss: 4.2028 - accuracy: 0.5035 - val_loss: 4.1997 - val_accuracy: 0.3679
# Epoch 27/100
# 4/4 [==============================] - 49s 11s/step - loss: 4.1593 - accuracy: 0.4563 - val_loss: 4.1547 - val_accuracy: 0.3491
# Epoch 28/100
# 4/4 [==============================] - 50s 11s/step - loss: 4.1106 - accuracy: 0.4846 - val_loss: 4.1592 - val_accuracy: 0.3962
# Epoch 29/100
# 4/4 [==============================] - 49s 11s/step - loss: 4.0803 - accuracy: 0.4846 - val_loss: 4.1021 - val_accuracy: 0.3962
# Epoch 30/100
# 4/4 [==============================] - 54s 13s/step - loss: 4.0098 - accuracy: 0.5296 - val_loss: 4.0588 - val_accuracy: 0.3774
# Epoch 31/100
# 4/4 [==============================] - 53s 12s/step - loss: 3.9686 - accuracy: 0.5059 - val_loss: 4.0507 - val_accuracy: 0.4151
# Epoch 32/100
# 4/4 [==============================] - 56s 13s/step - loss: 3.9562 - accuracy: 0.5154 - val_loss: 4.0106 - val_accuracy: 0.3868
# Epoch 33/100
# 4/4 [==============================] - 55s 12s/step - loss: 3.8910 - accuracy: 0.5532 - val_loss: 4.0068 - val_accuracy: 0.4340
# Epoch 34/100
# 4/4 [==============================] - 52s 12s/step - loss: 3.8545 - accuracy: 0.5485 - val_loss: 3.9692 - val_accuracy: 0.3962
# Epoch 35/100
# 4/4 [==============================] - 53s 12s/step - loss: 3.8261 - accuracy: 0.5296 - val_loss: 3.9310 - val_accuracy: 0.4151
# Epoch 36/100
# 4/4 [==============================] - 51s 11s/step - loss: 3.8033 - accuracy: 0.5154 - val_loss: 3.9244 - val_accuracy: 0.3774
# Epoch 37/100
# 4/4 [==============================] - 51s 12s/step - loss: 3.7644 - accuracy: 0.5319 - val_loss: 3.9323 - val_accuracy: 0.3962
# Epoch 38/100
# 4/4 [==============================] - 47s 11s/step - loss: 3.7452 - accuracy: 0.5626 - val_loss: 3.9158 - val_accuracy: 0.3774
# Epoch 39/100
# 4/4 [==============================] - 52s 13s/step - loss: 3.6919 - accuracy: 0.5603 - val_loss: 3.9167 - val_accuracy: 0.3679
# Epoch 40/100
# 4/4 [==============================] - 51s 11s/step - loss: 3.6940 - accuracy: 0.5225 - val_loss: 3.9020 - val_accuracy: 0.3868
# Epoch 41/100
# 4/4 [==============================] - 49s 11s/step - loss: 3.6676 - accuracy: 0.5343 - val_loss: 3.8724 - val_accuracy: 0.4057
# Epoch 42/100
# 4/4 [==============================] - 49s 11s/step - loss: 3.6403 - accuracy: 0.5508 - val_loss: 3.8198 - val_accuracy: 0.4151
# Epoch 43/100
# 4/4 [==============================] - 52s 12s/step - loss: 3.5810 - accuracy: 0.5934 - val_loss: 3.7774 - val_accuracy: 0.4151
# Epoch 44/100
# 4/4 [==============================] - 52s 12s/step - loss: 3.5636 - accuracy: 0.5579 - val_loss: 3.7489 - val_accuracy: 0.4057
# Epoch 45/100
# 4/4 [==============================] - 53s 12s/step - loss: 3.5100 - accuracy: 0.6005 - val_loss: 3.7366 - val_accuracy: 0.4245
# Epoch 46/100
# 4/4 [==============================] - 52s 12s/step - loss: 3.5035 - accuracy: 0.5910 - val_loss: 3.7050 - val_accuracy: 0.4434
# Epoch 47/100
# 4/4 [==============================] - 50s 11s/step - loss: 3.4659 - accuracy: 0.5957 - val_loss: 3.6711 - val_accuracy: 0.4717
# Epoch 48/100
# 4/4 [==============================] - 45s 10s/step - loss: 3.4346 - accuracy: 0.6147 - val_loss: 3.6922 - val_accuracy: 0.4151
# Epoch 49/100
# 4/4 [==============================] - 48s 11s/step - loss: 3.4074 - accuracy: 0.6194 - val_loss: 3.6582 - val_accuracy: 0.4340
# Epoch 50/100
# 4/4 [==============================] - 52s 12s/step - loss: 3.3666 - accuracy: 0.6265 - val_loss: 3.6204 - val_accuracy: 0.4623
# Epoch 51/100
# 4/4 [==============================] - 46s 10s/step - loss: 3.3526 - accuracy: 0.6099 - val_loss: 3.6211 - val_accuracy: 0.4340
# Epoch 52/100
# 4/4 [==============================] - 50s 12s/step - loss: 3.3234 - accuracy: 0.6312 - val_loss: 3.6145 - val_accuracy: 0.4151
# Epoch 53/100
# 4/4 [==============================] - 47s 10s/step - loss: 3.2965 - accuracy: 0.6265 - val_loss: 3.5954 - val_accuracy: 0.4528
# Epoch 54/100
# 4/4 [==============================] - 46s 10s/step - loss: 3.2566 - accuracy: 0.6501 - val_loss: 3.5544 - val_accuracy: 0.4434
# Epoch 55/100
# 4/4 [==============================] - 50s 12s/step - loss: 3.2403 - accuracy: 0.6525 - val_loss: 3.5572 - val_accuracy: 0.4434
# Epoch 56/100
# 4/4 [==============================] - 47s 11s/step - loss: 3.2049 - accuracy: 0.6596 - val_loss: 3.5437 - val_accuracy: 0.4434
# Epoch 57/100
# 4/4 [==============================] - 46s 11s/step - loss: 3.1892 - accuracy: 0.6572 - val_loss: 3.5476 - val_accuracy: 0.4528
# Epoch 58/100
# 4/4 [==============================] - 61s 14s/step - loss: 3.1856 - accuracy: 0.6738 - val_loss: 3.5439 - val_accuracy: 0.4434
# Epoch 59/100
# 4/4 [==============================] - 55s 12s/step - loss: 3.1304 - accuracy: 0.6950 - val_loss: 3.4912 - val_accuracy: 0.4623
# Epoch 60/100
# 4/4 [==============================] - 48s 11s/step - loss: 3.1071 - accuracy: 0.6950 - val_loss: 3.4726 - val_accuracy: 0.4528
# Epoch 61/100
# 4/4 [==============================] - 47s 11s/step - loss: 3.0835 - accuracy: 0.6879 - val_loss: 3.4791 - val_accuracy: 0.4623
# Epoch 62/100
# 4/4 [==============================] - 47s 11s/step - loss: 3.0666 - accuracy: 0.7069 - val_loss: 3.5175 - val_accuracy: 0.4528
# Epoch 63/100
# 4/4 [==============================] - 51s 12s/step - loss: 3.0670 - accuracy: 0.6879 - val_loss: 3.4378 - val_accuracy: 0.4811
# Epoch 64/100
# 4/4 [==============================] - 49s 12s/step - loss: 3.0291 - accuracy: 0.7139 - val_loss: 3.5053 - val_accuracy: 0.4434
# Epoch 65/100
# 4/4 [==============================] - 55s 13s/step - loss: 3.0058 - accuracy: 0.7281 - val_loss: 3.4287 - val_accuracy: 0.4717
# Epoch 66/100
# 4/4 [==============================] - 49s 12s/step - loss: 2.9883 - accuracy: 0.7069 - val_loss: 3.4703 - val_accuracy: 0.4528
# Epoch 67/100
# 4/4 [==============================] - 53s 12s/step - loss: 2.9716 - accuracy: 0.7210 - val_loss: 3.4290 - val_accuracy: 0.4623
# Epoch 68/100
# 4/4 [==============================] - 46s 10s/step - loss: 2.9643 - accuracy: 0.7234 - val_loss: 3.3877 - val_accuracy: 0.4717
# Epoch 69/100
# 4/4 [==============================] - 48s 11s/step - loss: 2.9409 - accuracy: 0.7258 - val_loss: 3.5203 - val_accuracy: 0.4434
# Epoch 70/100
# 4/4 [==============================] - 49s 11s/step - loss: 2.9530 - accuracy: 0.6950 - val_loss: 3.4124 - val_accuracy: 0.4811
# Epoch 71/100
# 4/4 [==============================] - 53s 12s/step - loss: 2.9264 - accuracy: 0.7092 - val_loss: 3.4727 - val_accuracy: 0.4623
# Epoch 72/100
# 4/4 [==============================] - 52s 12s/step - loss: 2.8981 - accuracy: 0.7376 - val_loss: 3.3588 - val_accuracy: 0.4717
# Epoch 73/100
# 4/4 [==============================] - 50s 11s/step - loss: 2.8987 - accuracy: 0.7352 - val_loss: 3.4777 - val_accuracy: 0.4434
# Epoch 74/100
# 4/4 [==============================] - 47s 10s/step - loss: 2.8820 - accuracy: 0.7116 - val_loss: 3.3329 - val_accuracy: 0.5000
# Epoch 75/100
# 4/4 [==============================] - 48s 11s/step - loss: 2.8409 - accuracy: 0.7612 - val_loss: 3.3435 - val_accuracy: 0.5000
# Epoch 76/100
# 4/4 [==============================] - 49s 11s/step - loss: 2.8321 - accuracy: 0.7400 - val_loss: 3.3897 - val_accuracy: 0.4906
# Epoch 77/100
# 4/4 [==============================] - 48s 11s/step - loss: 2.7871 - accuracy: 0.7778 - val_loss: 3.3529 - val_accuracy: 0.4717
# Epoch 78/100
# 4/4 [==============================] - 52s 12s/step - loss: 2.7657 - accuracy: 0.7896 - val_loss: 3.3476 - val_accuracy: 0.4906
# Epoch 79/100
# 4/4 [==============================] - 51s 11s/step - loss: 2.7500 - accuracy: 0.7849 - val_loss: 3.3977 - val_accuracy: 0.4906
# Epoch 80/100
# 4/4 [==============================] - 49s 11s/step - loss: 2.7355 - accuracy: 0.7754 - val_loss: 3.4202 - val_accuracy: 0.4717
# Epoch 81/100
# 4/4 [==============================] - 47s 11s/step - loss: 2.7199 - accuracy: 0.7872 - val_loss: 3.3394 - val_accuracy: 0.4717
# Epoch 82/100
# 4/4 [==============================] - 50s 12s/step - loss: 2.7065 - accuracy: 0.8085 - val_loss: 3.3458 - val_accuracy: 0.5283
# Epoch 83/100
# 4/4 [==============================] - 49s 11s/step - loss: 2.6865 - accuracy: 0.7683 - val_loss: 3.3035 - val_accuracy: 0.5094
# Epoch 84/100
# 4/4 [==============================] - 50s 11s/step - loss: 2.7169 - accuracy: 0.7778 - val_loss: 3.4354 - val_accuracy: 0.4623
# Epoch 85/100
# 4/4 [==============================] - 49s 11s/step - loss: 2.6769 - accuracy: 0.7896 - val_loss: 3.4063 - val_accuracy: 0.5000
# Epoch 86/100
# 4/4 [==============================] - 47s 10s/step - loss: 2.6541 - accuracy: 0.8061 - val_loss: 3.4252 - val_accuracy: 0.4623
# Epoch 87/100
# 4/4 [==============================] - 47s 11s/step - loss: 2.6401 - accuracy: 0.7967 - val_loss: 3.3257 - val_accuracy: 0.4623
# Epoch 88/100
# 4/4 [==============================] - 52s 12s/step - loss: 2.5872 - accuracy: 0.8369 - val_loss: 3.3529 - val_accuracy: 0.5094
# Epoch 89/100
# 4/4 [==============================] - 54s 13s/step - loss: 2.5544 - accuracy: 0.8511 - val_loss: 3.3589 - val_accuracy: 0.4811
# Epoch 90/100
# 4/4 [==============================] - 48s 11s/step - loss: 2.5672 - accuracy: 0.8298 - val_loss: 3.3725 - val_accuracy: 0.4717
# Epoch 91/100
# 4/4 [==============================] - 48s 11s/step - loss: 2.5330 - accuracy: 0.8322 - val_loss: 3.4191 - val_accuracy: 0.4811
# Epoch 92/100
# 4/4 [==============================] - 49s 12s/step - loss: 2.5551 - accuracy: 0.8203 - val_loss: 3.4773 - val_accuracy: 0.4623
# Epoch 93/100
# 4/4 [==============================] - 45s 10s/step - loss: 2.5341 - accuracy: 0.8274 - val_loss: 3.3990 - val_accuracy: 0.5000
# Epoch 94/100
# 4/4 [==============================] - 50s 12s/step - loss: 2.5326 - accuracy: 0.8180 - val_loss: 3.3356 - val_accuracy: 0.5000
# Epoch 95/100
# 4/4 [==============================] - 53s 11s/step - loss: 2.4822 - accuracy: 0.8629 - val_loss: 3.3506 - val_accuracy: 0.4811
# Epoch 96/100
# 4/4 [==============================] - 49s 11s/step - loss: 2.4527 - accuracy: 0.8487 - val_loss: 3.3247 - val_accuracy: 0.5000
# Epoch 97/100
# 4/4 [==============================] - 45s 10s/step - loss: 2.4419 - accuracy: 0.8534 - val_loss: 3.3364 - val_accuracy: 0.5000
# Epoch 98/100
# 4/4 [==============================] - 51s 13s/step - loss: 2.4455 - accuracy: 0.8274 - val_loss: 3.4459 - val_accuracy: 0.5000
# Epoch 99/100
# 4/4 [==============================] - 43s 10s/step - loss: 2.4277 - accuracy: 0.8723 - val_loss: 3.3462 - val_accuracy: 0.4811
# Epoch 100/100
# 4/4 [==============================] - 47s 11s/step - loss: 2.4008 - accuracy: 0.8700 - val_loss: 3.3873 - val_accuracy: 0.5377

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 1s 448ms/step
# 2/2 [==============================] - 1s 601ms/step - loss: 3.3079 - accuracy: 0.5424
# Accuracy over the test set:
#   54.24 %

# %%
# Plotting image to compare
dog=5

plt.imshow(X_test[dog,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[dog])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[dog])])
# Out:
# Originally :  scottish_deerhound
# Predicted :  scottish_deerhound
